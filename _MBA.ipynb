# %%
# Import packages
import pandas as pd
import numpy as np
import datetime as dt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, ward
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN, KMeans, AgglomerativeClustering
from sklearn.base import clone
from scipy.cluster.hierarchy import dendrogram
from sklearn.neighbors import NearestNeighbors
from yellowbrick.cluster import KElbowVisualizer
from math import ceil
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")
import squarify
import matplotlib

# %%
departments = pd.read_csv('departments.csv')
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# Import order product dataset
order_prod = pd.read_csv('order_products.csv', usecols=['order_id', 'product_id'])
order_prod.head()
# Out:
#    order_id  product_id
# 0        10          24
# 1        10          83
# 2        10          16
# 3        10          24
# 4        10          83

# %%
print('Total amount of unique order ids are:',len(order_prod['order_id'].unique()))
# Out:
# Total amount of unique order ids are: 200000

# %%
# Import order product dataset
orders = pd.read_csv('orders.csv')
orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2425083    49125             1          2                 18
# 1   1944304   162867             1          3                 17
# 2   1201011   147243            14          0                 16
# 3   1906860   195275            81          1                 11
# 4   2766469    58222             3          6                 11
#
#    days_since_prior_order
# 0                     NaN
# 1                     NaN
# 2                     3.0
# 3                     3.0
# 4                     6.0

# %%
# Import product label mapping
products = pd.read_csv('products.csv')
products.head()
# Out:
#    product_id  department_id                product_name
# 0          61             19               cookies cakes
# 1         104             13           spices seasonings
# 2          94              7                         tea
# 3          38              1                frozen meals
# 4           5             13  marinades meat preparation

# %%
# Merge product labels
df = pd.merge(order_prod, products, how='left', on='product_id').\
    drop(["product_id", "department_id"], axis=1)
df.head()
# Out:
#    order_id      product_name
# 0        10      fresh fruits
# 1        10  fresh vegetables
# 2        10       fresh herbs
# 3        10      fresh fruits
# 4        10  fresh vegetables

# %%
# Get modes and unique values
df.astype(object).describe()
# Out:
#         order_id  product_name
# count    2019501       2019501
# unique    200000           134
# top       790903  fresh fruits
# freq         137        226039

# %%
# Check product frequencies
df['product_name'].value_counts()
# Out:
# fresh fruits                  226039
# fresh vegetables              212611
# packaged vegetables fruits    109596
# yogurt                         90751
# packaged cheese                61502
#                                ...
# kitchen supplies                 561
# baby bath body care              515
# baby accessories                 504
# beauty                           387
# frozen juice                     279
# Name: product_name, Length: 134, dtype: int64

# %%
df['product_name'].value_counts(normalize=True)
# Out:
# fresh fruits                  0.111928
# fresh vegetables              0.105279
# packaged vegetables fruits    0.054269
# yogurt                        0.044937
# packaged cheese               0.030454
#                                 ...
# kitchen supplies              0.000278
# baby bath body care           0.000255
# baby accessories              0.000250
# beauty                        0.000192
# frozen juice                  0.000138
# Name: product_name, Length: 134, dtype: float64

# %%
# Pivot the data - lines as orders and products as columns
pt = pd.pivot_table(df, index='order_id', columns='product_name', 
                    aggfunc=lambda x: 1 if len(x)>0 else 0).fillna(0)
pt.head()
# Out:
# product_name  air fresheners candles  asian foods  baby accessories  \
# order_id
# 10                               0.0          0.0               0.0
# 11                               0.0          0.0               0.0
# 28                               0.0          0.0               0.0
# 38                               0.0          0.0               0.0
# 56                               0.0          0.0               0.0
#
# product_name  baby bath body care  baby food formula  bakery desserts  \
# order_id
# 10                            0.0                1.0              0.0
# 11                            0.0                0.0              0.0
# 28                            0.0                0.0              0.0
# 38                            0.0                0.0              0.0
# 56                            0.0                0.0              0.0
#
# product_name  baking ingredients  baking supplies decor  beauty  \
# order_id
# 10                           0.0                    0.0     0.0
# 11                           0.0                    0.0     0.0
# 28                           0.0                    0.0     0.0
# 38                           0.0                    0.0     0.0
# 56                           0.0                    0.0     0.0
#
# product_name  beers coolers  ...  spreads  tea  tofu meat alternatives  \
# order_id                     ...
# 10                      0.0  ...      0.0  0.0                     0.0
# 11                      0.0  ...      0.0  0.0                     0.0
# 28                      0.0  ...      1.0  0.0                     0.0
# 38                      0.0  ...      0.0  0.0                     0.0
# 56                      0.0  ...      0.0  0.0                     0.0
#
# product_name  tortillas flat bread  trail mix snack mix  trash bags liners  \
# order_id
# 10                             0.0                  0.0                0.0
# 11                             0.0                  0.0                0.0
# 28                             0.0                  0.0                0.0
# 38                             0.0                  0.0                0.0
# 56                             0.0                  0.0                0.0
#
# product_name  vitamins supplements  water seltzer sparkling water  \
# order_id
# 10                             0.0                            0.0
# 11                             0.0                            0.0
# 28                             0.0                            0.0
# 38                             0.0                            0.0
# 56                             0.0                            0.0
#
# product_name  white wines  yogurt
# order_id
# 10                    0.0     0.0
# 11                    0.0     0.0
# 28                    0.0     1.0
# 38                    0.0     0.0
# 56                    0.0     0.0
#
# [5 rows x 134 columns]

# %% [markdown]
# ## Beginning of MBA

# %% [markdown]
# ### Support

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% or 2.5% of the transactions (more info at http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
frequent_itemsets = apriori(pt, min_support=0.025, use_colnames=True)
frequent_itemsets.head()
# Out:
#     support              itemsets
# 0  0.043330         (asian foods)
# 1  0.045355   (baby food formula)
# 2  0.076635  (baking ingredients)
# 3  0.163865               (bread)
# 4  0.067765    (breakfast bakery)

# %% [markdown]
# ### Confidence

# %%
# Generate the association rules - by confidence
rulesConfidence = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.50)
rulesConfidence.sort_values(by='confidence', ascending=False, inplace=True)
rulesConfidence.head()
# Out:
#                                            antecedents         consequents  \
# 463  (fresh herbs, packaged vegetables fruits, fres...  (fresh vegetables)
# 557  (milk, packaged vegetables fruits, fresh veget...      (fresh fruits)
# 563  (packaged cheese, packaged vegetables fruits, ...      (fresh fruits)
# 338          (packaged vegetables fruits, fresh herbs)  (fresh vegetables)
# 551  (milk, packaged cheese, packaged vegetables fr...      (fresh fruits)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 463            0.043490            0.444360  0.039660    0.911934  2.052241
# 557            0.036455            0.555995  0.032845    0.900974  1.620471
# 563            0.038635            0.555995  0.034565    0.894655  1.609106
# 338            0.052535            0.444360  0.046980    0.894261  2.012470
# 551            0.032215            0.555995  0.028555    0.886388  1.594238
#
#      leverage  conviction
# 463  0.020335    6.309343
# 557  0.012576    4.483713
# 563  0.013084    4.214775
# 338  0.023636    5.254824
# 551  0.010644    3.908093

# %% [markdown]
# ### Lift

# %%
# Generate the association rules - by lift
rulesLift = association_rules(frequent_itemsets, metric="lift", min_threshold=1.3)
rulesLift.sort_values(by='lift', ascending=False, inplace=True)
rulesLift.head()
# Out:
#                                             antecedents  \
# 1983                         (fresh vegetables, yogurt)
# 1966  (packaged cheese, packaged vegetables fruits, ...
# 1951                         (fresh vegetables, yogurt)
# 1938   (milk, packaged vegetables fruits, fresh fruits)
# 1982               (packaged vegetables fruits, yogurt)
#
#                                             consequents  antecedent support  \
# 1983  (packaged cheese, packaged vegetables fruits, ...            0.144660
# 1966                         (fresh vegetables, yogurt)            0.090715
# 1951   (milk, packaged vegetables fruits, fresh fruits)            0.144660
# 1938                         (fresh vegetables, yogurt)            0.087450
# 1982  (packaged cheese, fresh vegetables, fresh fruits)            0.127910
#
#       consequent support   support  confidence      lift  leverage  conviction
# 1983            0.090715  0.034565    0.238940  2.633959  0.021442    1.194761
# 1966            0.144660  0.034565    0.381028  2.633959  0.021442    1.381873
# 1951            0.087450  0.032845    0.227050  2.596337  0.020194    1.180606
# 1938            0.144660  0.032845    0.375586  2.596337  0.020194    1.369828
# 1982            0.104570  0.034565    0.270229  2.584193  0.021189    1.227001

# %% [markdown]
# #### Rules are of type `frozenset`, which is a Python built-in type that behaves similarly to sets except that it is immutable. Frozensets have functions to check if there are subsets, supersets, etc. More info at https://www.journaldev.com/22850/python-frozenset
#
#
# ### EXPLORE FREQUENT_ITEMSETS

# %%
# Add a column with the length
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Length=2 and Support>=0.2
frequent_itemsets[(frequent_itemsets['length'] == 2) & (frequent_itemsets['support'] >= 0.2)]
# Out:
#       support                                        itemsets  length
# 180  0.317560                (fresh vegetables, fresh fruits)       2
# 200  0.269870      (packaged vegetables fruits, fresh fruits)       2
# 236  0.234555  (packaged vegetables fruits, fresh vegetables)       2

# %%
# fresh fruits and yogurt
frequent_itemsets[ frequent_itemsets['itemsets'] == {'yogurt', 'fresh fruits'}]
# Out:
#       support                itemsets  length
# 214  0.188225  (fresh fruits, yogurt)       2

# %%
# packaged cheese
frequent_itemsets[ frequent_itemsets['itemsets'] == {'packaged cheese'}]
# Out:
#      support           itemsets  length
# 46  0.230995  (packaged cheese)       1

# %%
# High Confidence and high Lift - complementary products
rulesConfidence[(rulesConfidence['confidence'] >= 0.8) & (rulesConfidence['lift'] >= 1.8)]
# Out:
#                                            antecedents         consequents  \
# 463  (fresh herbs, packaged vegetables fruits, fres...  (fresh vegetables)
# 338          (packaged vegetables fruits, fresh herbs)  (fresh vegetables)
# 228                        (fresh herbs, fresh fruits)  (fresh vegetables)
# 341                              (fresh herbs, yogurt)  (fresh vegetables)
# 412  (packaged vegetables fruits, fresh fruits, can...  (fresh vegetables)
# 337                     (fresh herbs, packaged cheese)  (fresh vegetables)
# 417  (packaged vegetables fruits, fresh fruits, can...  (fresh vegetables)
# 72                                       (fresh herbs)  (fresh vegetables)
# 137  (packaged vegetables fruits, canned jarred veg...  (fresh vegetables)
# 133           (fresh fruits, canned jarred vegetables)  (fresh vegetables)
# 508  (soup broth bouillon, packaged vegetables frui...  (fresh vegetables)
# 144   (packaged vegetables fruits, canned meals beans)  (fresh vegetables)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 463            0.043490             0.44436  0.039660    0.911934  2.052241
# 338            0.052535             0.44436  0.046980    0.894261  2.012470
# 228            0.070135             0.44436  0.061815    0.881372  1.983463
# 341            0.029480             0.44436  0.025975    0.881106  1.982865
# 412            0.029740             0.44436  0.026065    0.876429  1.972340
# 337            0.030290             0.44436  0.026460    0.873556  1.965874
# 417            0.030560             0.44436  0.025905    0.847677  1.907635
# 72             0.093005             0.44436  0.078655    0.845707  1.903203
# 137            0.037835             0.44436  0.031925    0.843795  1.898901
# 133            0.048880             0.44436  0.040955    0.837868  1.885562
# 508            0.031405             0.44436  0.025880    0.824073  1.854516
# 144            0.037670             0.44436  0.030555    0.811123  1.825373
#
#      leverage  conviction
# 463  0.020335    6.309343
# 338  0.023636    5.254824
# 228  0.030650    4.683872
# 341  0.012875    4.673400
# 412  0.012850    4.496526
# 337  0.013000    4.394343
# 417  0.012325    3.647768
# 72   0.037327    3.601205
# 137  0.015113    3.557130
# 133  0.019235    3.427089
# 508  0.011925    3.158348
# 144  0.013816    2.941807

# %%
# High Confidence rules where "fresh vegetables" and "fresh fruits" are in the LHS
rulesConfidence[rulesConfidence['antecedents']=={'fresh vegetables', 'fresh fruits'}]  # Because rules are a "frozenset" object, the order of items is not important
# Out:
#                           antecedents                   consequents  \
# 260  (fresh vegetables, fresh fruits)  (packaged vegetables fruits)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 260             0.31756            0.365415  0.18658    0.587543  1.607877
#
#      leverage  conviction
# 260  0.070539    1.538546

# %%
# High Confidence rules where "packaged vegetables fruits" is in the RHS
rulesConfidence[['packaged vegetables fruits' in elem for elem in rulesConfidence['consequents']]]
# Out:
#                                            antecedents  \
# 561  (packaged cheese, fresh vegetables, fresh frui...
# 458  (fresh dips tapenades, fresh vegetables, fresh...
# 550  (milk, packaged cheese, fresh vegetables, fres...
# 548        (packaged cheese, fresh vegetables, yogurt)
# 555     (milk, fresh vegetables, fresh fruits, yogurt)
# ..                                                 ...
# 464                    (fresh herbs, fresh vegetables)
# 31                                              (eggs)
# 494                (packaged cheese, fresh vegetables)
# 487                           (milk, fresh vegetables)
# 399                          (bread, fresh vegetables)
#
#                                     consequents  antecedent support  \
# 561                (packaged vegetables fruits)            0.049105
# 458                (packaged vegetables fruits)            0.046625
# 550                (packaged vegetables fruits)            0.041475
# 548                (packaged vegetables fruits)            0.057195
# 555                (packaged vegetables fruits)            0.048835
# ..                                          ...                 ...
# 464  (packaged vegetables fruits, fresh fruits)            0.078655
# 31                 (packaged vegetables fruits)            0.136490
# 494  (packaged vegetables fruits, fresh fruits)            0.135850
# 487  (packaged vegetables fruits, fresh fruits)            0.124715
# 399  (packaged vegetables fruits, fresh fruits)            0.091590
#
#      consequent support   support  confidence      lift  leverage  conviction
# 561            0.365415  0.034565    0.703900  1.926302  0.016621    2.143143
# 458            0.365415  0.032265    0.692011  1.893767  0.015228    2.060413
# 550            0.365415  0.028555    0.688487  1.884124  0.013399    2.037106
# 548            0.365415  0.038635    0.675496  1.848572  0.017735    1.955554
# 555            0.365415  0.032845    0.672571  1.840567  0.015000    1.938084
# ..                  ...       ...         ...       ...       ...         ...
# 464            0.269870  0.039660    0.504227  1.868408  0.018433    1.472711
# 31             0.365415  0.068650    0.502967  1.376427  0.018775    1.276747
# 494            0.269870  0.068325    0.502944  1.863654  0.031663    1.468910
# 487            0.269870  0.062535    0.501423  1.858018  0.028878    1.464428
# 399            0.269870  0.045910    0.501256  1.857397  0.021193    1.463936
#
# [142 rows x 9 columns]

# %%
# Substitue products
rulesLift2 = association_rules(frequent_itemsets, metric="lift", min_threshold=0.005)
rulesLift2.sort_values(by='lift', ascending=True, inplace=True)
rulesLift2.head(20)
# Out:
#                          antecedents                      consequents  \
# 345               (fresh vegetables)                    (soft drinks)
# 344                    (soft drinks)               (fresh vegetables)
# 275                   (fresh fruits)                    (soft drinks)
# 274                    (soft drinks)                   (fresh fruits)
# 264                    (paper goods)                   (fresh fruits)
# 265                   (fresh fruits)                    (paper goods)
# 66                (fresh vegetables)                (candy chocolate)
# 67                 (candy chocolate)               (fresh vegetables)
# 337               (fresh vegetables)                    (paper goods)
# 336                    (paper goods)               (fresh vegetables)
# 356  (water seltzer sparkling water)               (fresh vegetables)
# 357               (fresh vegetables)  (water seltzer sparkling water)
# 420                           (milk)  (water seltzer sparkling water)
# 421  (water seltzer sparkling water)                           (milk)
# 419                (soy lactosefree)                           (milk)
# 418                           (milk)                (soy lactosefree)
# 69                 (candy chocolate)     (packaged vegetables fruits)
# 68      (packaged vegetables fruits)                (candy chocolate)
# 135                   (fresh fruits)                         (coffee)
# 134                         (coffee)                   (fresh fruits)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 345            0.444360            0.087310  0.027845    0.062663  0.717709
# 344            0.087310            0.444360  0.027845    0.318921  0.717709
# 275            0.555995            0.087310  0.039585    0.071197  0.815447
# 274            0.087310            0.555995  0.039585    0.453384  0.815447
# 264            0.063575            0.555995  0.032090    0.504758  0.907847
# 265            0.555995            0.063575  0.032090    0.057716  0.907847
# 66             0.444360            0.069305  0.028210    0.063485  0.916017
# 67             0.069305            0.444360  0.028210    0.407041  0.916017
# 337            0.444360            0.063575  0.025885    0.058252  0.916277
# 336            0.063575            0.444360  0.025885    0.407157  0.916277
# 356            0.193005            0.444360  0.083355    0.431880  0.971915
# 357            0.444360            0.193005  0.083355    0.187584  0.971915
# 420            0.243325            0.193005  0.046610    0.191555  0.992485
# 421            0.193005            0.243325  0.046610    0.241496  0.992485
# 419            0.168355            0.243325  0.041220    0.244840  1.006225
# 418            0.243325            0.168355  0.041220    0.169403  1.006225
# 69             0.069305            0.365415  0.025520    0.368227  1.007696
# 68             0.365415            0.069305  0.025520    0.069838  1.007696
# 135            0.555995            0.055650  0.031855    0.057294  1.029536
# 134            0.055650            0.555995  0.031855    0.572417  1.029536
#
#      leverage  conviction
# 345 -0.010952    0.973705
# 344 -0.010952    0.815823
# 275 -0.008959    0.982652
# 274 -0.008959    0.812280
# 264 -0.003257    0.896542
# 265 -0.003257    0.993782
# 66  -0.002586    0.993785
# 67  -0.002586    0.937064
# 337 -0.002365    0.994348
# 336 -0.002365    0.937246
# 356 -0.002409    0.978033
# 357 -0.002409    0.993328
# 420 -0.000353    0.998206
# 421 -0.000353    0.997589
# 419  0.000255    1.002006
# 418  0.000255    1.001262
# 69   0.000195    1.004452
# 68   0.000195    1.000573
# 135  0.000914    1.001744
# 134  0.000914    1.038406

# %%
### Plot a basic network graph of the top 50 confidence rules
# Create a copy of the rules and transform the frozensets to strings
rulesToPlot = rulesConfidence.copy(deep=True)
rulesToPlot['LHS'] = [','.join(list(x)) for x in rulesToPlot['antecedents']]
rulesToPlot['RHS'] = [','.join(list(x)) for x in rulesToPlot['consequents']]
# Remove duplicate if reversed rules
rulesToPlot['sortedRow'] = [sorted([a,b]) for a,b in zip(rulesToPlot.LHS, rulesToPlot.RHS)]
rulesToPlot['sortedRow'] = rulesToPlot['sortedRow'].astype(str)
rulesToPlot.drop_duplicates(subset=['sortedRow'], inplace=True)
# Plot
rulesToPlot=rulesToPlot[:50]
fig = plt.figure(figsize=(20, 20)) 
G = nx.from_pandas_edgelist(rulesToPlot, 'LHS', 'RHS')  
# Each node is an itemset (either source or target) and the edges connect the itemsets if they consist of a high confidence rule
nx.draw(G, with_labels=True, node_size=30, node_color="red", pos=nx.spring_layout(G))
plt.axis('equal')
plt.show()
#fig.savefig('figure.svg')
# TRY TO PLOT THE DIRECTION OF SOURCE -> TARGET

# %% [markdown]
# # 1. Analysis Objectives
# <img src="img/lel.jpg" alt="ehm" width="600"/>

# %% [markdown]
# ### Objectives
# **You should aim to provide an overview of Instacart's business as
# complete as possible. Jane is particularly interested in the topics
# below:**
#
# * What are the main types of consumer behavior in the business? <br>
# * Which types of products should have an extended amount of product offerings? <br>
# * Which types of products can be seen as substitutes? <br>
# * Which items are complementary? <br>

# %% [markdown]
# ## Important:
# #### In the following and rest of this notebook, the focus will be mainly on Market Basket Analysis and especially finding the complementary and substitues with different thresholds

# %% [markdown]
# # 2. Checking for substitues

# %% [markdown]
# ### Which types of products can be seen as substitutes?
# If the lift is < 1, that lets us know the items are substitute to each other. This means that presence of one item has negative effect on presence of other item and vice versa. Below, the formula for calculating the Lift:
#
# $$Lift \: (x→y) = \frac{supp\:(x,y)}{supp\:(x)\: * supp\:(y)}$$

# %% [markdown]
# ## 2.1. Support at 5% (Experimenting)

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% of the transactions
frequent_itemsets_five = apriori(pt, min_support=0.05, use_colnames=True)
frequent_itemsets_five.head()
# Out:
#     support              itemsets
# 0  0.076635  (baking ingredients)
# 1  0.163865               (bread)
# 2  0.067765    (breakfast bakery)
# 3  0.074330              (butter)
# 4  0.069305     (candy chocolate)

# %%
# Generate the association rules - by lift with min threshold of 0.01
ruleLift = association_rules(frequent_itemsets_five, metric="lift", min_threshold=0.01)
ruleLift.sort_values(by='lift', ascending=True, inplace=True)
ruleLift.head()
# Out:
#                           antecedents                       consequents  \
# 110   (water seltzer sparkling water)                (fresh vegetables)
# 111                (fresh vegetables)   (water seltzer sparkling water)
# 232  (fresh vegetables, fresh fruits)   (water seltzer sparkling water)
# 233   (water seltzer sparkling water)  (fresh vegetables, fresh fruits)
# 82    (water seltzer sparkling water)                    (fresh fruits)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 110            0.193005            0.444360  0.083355    0.431880  0.971915
# 111            0.444360            0.193005  0.083355    0.187584  0.971915
# 232            0.317560            0.193005  0.063235    0.199128  1.031723
# 233            0.193005            0.317560  0.063235    0.327634  1.031723
# 82             0.193005            0.555995  0.111045    0.575348  1.034807
#
#      leverage  conviction
# 110 -0.002409    0.978033
# 111 -0.002409    0.993328
# 232  0.001944    1.007645
# 233  0.001944    1.014983
# 82   0.003735    1.045573

# %%
print('Amount of substitues found:',len(ruleLift[(ruleLift['lift'] < 1)]))
# Out:
# Amount of substitues found: 2

# %%
ruleSubs = ruleLift[(ruleLift['lift'] < 1)]
ruleSubs
# Out:
#                          antecedents                      consequents  \
# 110  (water seltzer sparkling water)               (fresh vegetables)
# 111               (fresh vegetables)  (water seltzer sparkling water)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 110            0.193005            0.444360  0.083355    0.431880  0.971915
# 111            0.444360            0.193005  0.083355    0.187584  0.971915
#
#      leverage  conviction
# 110 -0.002409    0.978033
# 111 -0.002409    0.993328

# %%
ruleSubs['length_ant'] = ruleSubs['antecedents'].apply(lambda x: len(x))
ruleSubs['length_cons'] = ruleSubs['consequents'].apply(lambda x: len(x))
# Out:
# <ipython-input-27-9115b09d29ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleSubs['length_ant'] = ruleSubs['antecedents'].apply(lambda x: len(x))
# <ipython-input-27-9115b09d29ab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleSubs['length_cons'] = ruleSubs['consequents'].apply(lambda x: len(x))

# %% [markdown]
# ## 2.2. Support at 2.5% (Chosen)

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 2.5% of the transactions
frequent_itemsets_twofive = apriori(pt, min_support=0.025, use_colnames=True)
frequent_itemsets_twofive.head()
# Out:
#     support              itemsets
# 0  0.043330         (asian foods)
# 1  0.045355   (baby food formula)
# 2  0.076635  (baking ingredients)
# 3  0.163865               (bread)
# 4  0.067765    (breakfast bakery)

# %%
# Generate the association rules - by lift with min threshold of 0.01
ruleLift = association_rules(frequent_itemsets_twofive, metric="lift", min_threshold=0.01)
ruleLift.sort_values(by='lift', ascending=True, inplace=True)
ruleLift.head()
# Out:
#             antecedents         consequents  antecedent support  \
# 345  (fresh vegetables)       (soft drinks)            0.444360
# 344       (soft drinks)  (fresh vegetables)            0.087310
# 275      (fresh fruits)       (soft drinks)            0.555995
# 274       (soft drinks)      (fresh fruits)            0.087310
# 264       (paper goods)      (fresh fruits)            0.063575
#
#      consequent support   support  confidence      lift  leverage  conviction
# 345            0.087310  0.027845    0.062663  0.717709 -0.010952    0.973705
# 344            0.444360  0.027845    0.318921  0.717709 -0.010952    0.815823
# 275            0.087310  0.039585    0.071197  0.815447 -0.008959    0.982652
# 274            0.555995  0.039585    0.453384  0.815447 -0.008959    0.812280
# 264            0.555995  0.032090    0.504758  0.907847 -0.003257    0.896542

# %% [markdown]
# ## 2.3. Scatter plot - Confidence vs Support

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x = "support", y = "confidence", data = ruleLift)
plt.margins(0.01,0.01)
plt.savefig('scatter_conf_support.png',bbox_inches='tight',dpi=250, transparent=True)
plt.show()

# %%
print('Amount of substitues found:',len(ruleLift[(ruleLift['lift'] < 1) & (ruleLift['confidence'] > 0.1)]))
# Out:
# Amount of substitues found: 9

# %% [markdown]
# ## 2.4 Table - Substitute itemsets

# %%
ruleSubs = ruleLift[(ruleLift['lift'] < 1) & (ruleLift['confidence'] > 0.15)]
ruleSubs.reset_index(drop=True, inplace=True)
ruleSubs
# Out:
#                        antecedents                      consequents  \
# 0                    (soft drinks)               (fresh vegetables)
# 1                    (soft drinks)                   (fresh fruits)
# 2                    (paper goods)                   (fresh fruits)
# 3                (candy chocolate)               (fresh vegetables)
# 4                    (paper goods)               (fresh vegetables)
# 5  (water seltzer sparkling water)               (fresh vegetables)
# 6               (fresh vegetables)  (water seltzer sparkling water)
# 7                           (milk)  (water seltzer sparkling water)
# 8  (water seltzer sparkling water)                           (milk)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.087310            0.444360  0.027845    0.318921  0.717709
# 1            0.087310            0.555995  0.039585    0.453384  0.815447
# 2            0.063575            0.555995  0.032090    0.504758  0.907847
# 3            0.069305            0.444360  0.028210    0.407041  0.916017
# 4            0.063575            0.444360  0.025885    0.407157  0.916277
# 5            0.193005            0.444360  0.083355    0.431880  0.971915
# 6            0.444360            0.193005  0.083355    0.187584  0.971915
# 7            0.243325            0.193005  0.046610    0.191555  0.992485
# 8            0.193005            0.243325  0.046610    0.241496  0.992485
#
#    leverage  conviction
# 0 -0.010952    0.815823
# 1 -0.008959    0.812280
# 2 -0.003257    0.896542
# 3 -0.002586    0.937064
# 4 -0.002365    0.937246
# 5 -0.002409    0.978033
# 6 -0.002409    0.993328
# 7 -0.000353    0.998206
# 8 -0.000353    0.997589

# %%
ruleSubs['length_ant'] = ruleSubs['antecedents'].apply(lambda x: len(x))
ruleSubs['length_cons'] = ruleSubs['consequents'].apply(lambda x: len(x))
# Out:
# <ipython-input-33-9115b09d29ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleSubs['length_ant'] = ruleSubs['antecedents'].apply(lambda x: len(x))
# <ipython-input-33-9115b09d29ab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleSubs['length_cons'] = ruleSubs['consequents'].apply(lambda x: len(x))

# %% [markdown]
# ## 2.4. Heatmap - Substitute itemsets

# %%
# Import seaborn under its standard alias
import seaborn as sns

# Replace frozen sets with strings
ruleSubs['antecedents_'] = ruleSubs['antecedents'].apply(lambda a: ','.join(list(a)))
ruleSubs['consequents_'] = ruleSubs['consequents'].apply(lambda a: ','.join(list(a)))


# Transform the DataFrame of rules into a matrix using the lift metric
pivot = ruleSubs[ruleSubs['length_ant']==1].pivot(index = 'antecedents_', 
                    columns = 'consequents_', values= 'lift')

# Generate a heatmap with annotations on and the colorbar off
fig, ax = plt.subplots(figsize=(5,6)) 
sns.heatmap(pivot, annot = True, linewidths=.5,ax=ax, cmap="YlGnBu").set_title("Substitues")
plt.yticks(rotation=45)
plt.xticks(rotation=45)
plt.savefig('all_subs_heatmap.png',bbox_inches='tight',dpi=250, transparent=True)
plt.show()
# Out:
# <ipython-input-34-0a45189a113c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleSubs['antecedents_'] = ruleSubs['antecedents'].apply(lambda a: ','.join(list(a)))
# <ipython-input-34-0a45189a113c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleSubs['consequents_'] = ruleSubs['consequents'].apply(lambda a: ','.join(list(a)))

# %% [markdown]
# # 3. Checking for complementaries
# ### Which types of products can be seen as complementaries?
#
# If the lift is > 1, that lets us know the degree to which those two occurrences are dependent on one another, and makes those rules potentially useful for predicting the consequent in future data sets.

# %% [markdown]
# ## 3.1. Support at 5%

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% of the transactions
frequent_itemsets_five = apriori(pt, min_support=0.05, use_colnames=True)
frequent_itemsets_five.head()
# Out:
#     support              itemsets
# 0  0.076635  (baking ingredients)
# 1  0.163865               (bread)
# 2  0.067765    (breakfast bakery)
# 3  0.074330              (butter)
# 4  0.069305     (candy chocolate)

# %%
# Generate the association rules - by lift with min threshold of 0.01
ruleLift = association_rules(frequent_itemsets_five, metric="lift", min_threshold=0.01)
ruleLift.sort_values(by='lift', ascending=False, inplace=True)
ruleLift.head()
# Out:
#                                     antecedents  \
# 191                               (fresh herbs)
# 190            (fresh vegetables, fresh fruits)
# 192                          (fresh vegetables)
# 189                 (fresh herbs, fresh fruits)
# 377  (packaged vegetables fruits, fresh fruits)
#
#                           consequents  antecedent support  consequent support  \
# 191  (fresh vegetables, fresh fruits)            0.093005            0.317560
# 190                     (fresh herbs)            0.317560            0.093005
# 192       (fresh herbs, fresh fruits)            0.444360            0.070135
# 189                (fresh vegetables)            0.070135            0.444360
# 377        (fresh vegetables, yogurt)            0.269870            0.144660
#
#       support  confidence      lift  leverage  conviction
# 191  0.061815    0.664642  2.092964  0.032280    2.034958
# 190  0.061815    0.194656  2.092964  0.032280    1.126221
# 192  0.061815    0.139110  1.983463  0.030650    1.080121
# 189  0.061815    0.881372  1.983463  0.030650    4.683872
# 377  0.076240    0.282506  1.952899  0.037201    1.192122

# %%
print('Amount of substitues found:',len(ruleLift[(ruleLift['lift'] > 1)]))
# Out:
# Amount of substitues found: 384

# %%
ruleCom = ruleLift[(ruleLift['lift'] > 1)]
ruleCom.reset_index(drop=True, inplace=True)
ruleCom
# Out:
#                                     antecedents  \
# 0                                 (fresh herbs)
# 1              (fresh vegetables, fresh fruits)
# 2                            (fresh vegetables)
# 3                   (fresh herbs, fresh fruits)
# 4    (packaged vegetables fruits, fresh fruits)
# ..                                          ...
# 379                (packaged vegetables fruits)
# 380             (water seltzer sparkling water)
# 381                              (fresh fruits)
# 382             (water seltzer sparkling water)
# 383            (fresh vegetables, fresh fruits)
#
#                           consequents  antecedent support  consequent support  \
# 0    (fresh vegetables, fresh fruits)            0.093005            0.317560
# 1                       (fresh herbs)            0.317560            0.093005
# 2         (fresh herbs, fresh fruits)            0.444360            0.070135
# 3                  (fresh vegetables)            0.070135            0.444360
# 4          (fresh vegetables, yogurt)            0.269870            0.144660
# ..                                ...                 ...                 ...
# 379   (water seltzer sparkling water)            0.365415            0.193005
# 380                    (fresh fruits)            0.193005            0.555995
# 381   (water seltzer sparkling water)            0.555995            0.193005
# 382  (fresh vegetables, fresh fruits)            0.193005            0.317560
# 383   (water seltzer sparkling water)            0.317560            0.193005
#
#       support  confidence      lift  leverage  conviction
# 0    0.061815    0.664642  2.092964  0.032280    2.034958
# 1    0.061815    0.194656  2.092964  0.032280    1.126221
# 2    0.061815    0.139110  1.983463  0.030650    1.080121
# 3    0.061815    0.881372  1.983463  0.030650    4.683872
# 4    0.076240    0.282506  1.952899  0.037201    1.192122
# ..        ...         ...       ...       ...         ...
# 379  0.073715    0.201730  1.045204  0.003188    1.010929
# 380  0.111045    0.575348  1.034807  0.003735    1.045573
# 381  0.111045    0.199723  1.034807  0.003735    1.008395
# 382  0.063235    0.327634  1.031723  0.001944    1.014983
# 383  0.063235    0.199128  1.031723  0.001944    1.007645
#
# [384 rows x 9 columns]

# %%
ruleCom['length_ant'] = ruleCom['antecedents'].apply(lambda x: len(x))
ruleCom['length_cons'] = ruleCom['consequents'].apply(lambda x: len(x))
# Out:
# <ipython-input-39-79af7efe56d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleCom['length_ant'] = ruleCom['antecedents'].apply(lambda x: len(x))
# <ipython-input-39-79af7efe56d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleCom['length_cons'] = ruleCom['consequents'].apply(lambda x: len(x))

# %%
rule_Com_new = ruleCom[(ruleCom['lift'] > 1) &
        (ruleCom['confidence'] > 0.15) &
        (ruleCom['length_ant'] <= 2) &
        (ruleCom['length_cons'] == 1)]
rule_Com_new.head(20)
# Out:
#                                       antecedents  \
# 1                (fresh vegetables, fresh fruits)
# 3                     (fresh herbs, fresh fruits)
# 6                                   (fresh herbs)
# 7                              (fresh vegetables)
# 21             (milk, packaged vegetables fruits)
# 26           (packaged vegetables fruits, yogurt)
# 28                           (milk, fresh fruits)
# 33                     (canned jarred vegetables)
# 35                       (milk, fresh vegetables)
# 39  (packaged vegetables fruits, packaged cheese)
# 41                     (fresh vegetables, yogurt)
# 43                (packaged cheese, fresh fruits)
# 47            (fresh vegetables, soy lactosefree)
# 49                 (frozen produce, fresh fruits)
# 51                     (fresh vegetables, yogurt)
# 52             (packaged vegetables fruits, eggs)
# 55            (packaged cheese, fresh vegetables)
# 56           (packaged vegetables fruits, yogurt)
# 58     (packaged vegetables fruits, fresh fruits)
# 60                       (fresh vegetables, eggs)
#
#                      consequents  antecedent support  consequent support  \
# 1                  (fresh herbs)            0.317560            0.093005
# 3             (fresh vegetables)            0.070135            0.444360
# 6             (fresh vegetables)            0.093005            0.444360
# 7                  (fresh herbs)            0.444360            0.093005
# 21                      (yogurt)            0.107425            0.263675
# 26             (packaged cheese)            0.127910            0.230995
# 28                      (yogurt)            0.164310            0.263675
# 33            (fresh vegetables)            0.071890            0.444360
# 35                      (yogurt)            0.124715            0.263675
# 39                      (yogurt)            0.114610            0.263675
# 41             (packaged cheese)            0.144660            0.230995
# 43                      (yogurt)            0.155900            0.263675
# 47  (packaged vegetables fruits)            0.094120            0.365415
# 49  (packaged vegetables fruits)            0.089235            0.365415
# 51  (packaged vegetables fruits)            0.144660            0.365415
# 52            (fresh vegetables)            0.068650            0.444360
# 55  (packaged vegetables fruits)            0.135850            0.365415
# 56                        (milk)            0.127910            0.243325
# 58              (frozen produce)            0.269870            0.122580
# 60  (packaged vegetables fruits)            0.084310            0.365415
#
#      support  confidence      lift  leverage  conviction  length_ant  \
# 1   0.061815    0.194656  2.092964  0.032280    1.126221           2
# 3   0.061815    0.881372  1.983463  0.030650    4.683872           2
# 6   0.078655    0.845707  1.903203  0.037327    3.601205           1
# 7   0.078655    0.177007  1.903203  0.037327    1.102069           1
# 21  0.051295    0.477496  1.810926  0.022970    1.409223           2
# 26  0.051915    0.405871  1.757057  0.022368    1.294341           2
# 28  0.074860    0.455602  1.727893  0.031536    1.352550           2
# 33  0.055055    0.765823  1.723429  0.023110    2.372733           1
# 35  0.056510    0.453113  1.718453  0.023626    1.346394           2
# 39  0.051915    0.452971  1.717914  0.021695    1.346044           2
# 41  0.057195    0.395375  1.711619  0.023779    1.271872           2
# 43  0.070020    0.449134  1.703362  0.028913    1.336668           2
# 47  0.057695    0.612994  1.677528  0.023302    1.639729           2
# 49  0.054415    0.609794  1.668772  0.021807    1.626284           2
# 51  0.087995    0.608288  1.664651  0.035134    1.620031           2
# 52  0.050675    0.738165  1.661186  0.020170    2.122097           2
# 55  0.081970    0.603386  1.651235  0.032328    1.600007           2
# 56  0.051295    0.401024  1.648101  0.020171    1.263281           2
# 58  0.054415    0.201634  1.644919  0.021334    1.099020           2
# 60  0.050675    0.601056  1.644858  0.019867    1.590660           2
#
#     length_cons
# 1             1
# 3             1
# 6             1
# 7             1
# 21            1
# 26            1
# 28            1
# 33            1
# 35            1
# 39            1
# 41            1
# 43            1
# 47            1
# 49            1
# 51            1
# 52            1
# 55            1
# 56            1
# 58            1
# 60            1

# %%
print('Amount of complementaries found:',len(rule_Com_new))
# Out:
# Amount of complementaries found: 213

# %% [markdown]
# ## 3.2. Support at 2.5%

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 2.5% of the transactions
frequent_itemsets_twofive = apriori(pt, min_support=0.025, use_colnames=True)
frequent_itemsets_twofive.head()
# Out:
#     support              itemsets
# 0  0.043330         (asian foods)
# 1  0.045355   (baby food formula)
# 2  0.076635  (baking ingredients)
# 3  0.163865               (bread)
# 4  0.067765    (breakfast bakery)

# %%
# Generate the association rules - by lift with min threshold of 0.01
ruleLift_five = association_rules(frequent_itemsets_twofive, metric="lift", min_threshold=0.01)
ruleLift_five.sort_values(by='lift', ascending=False, inplace=True)
ruleLift_five.head()
# Out:
#                                             antecedents  \
# 2350  (packaged cheese, packaged vegetables fruits, ...
# 2367                         (fresh vegetables, yogurt)
# 2335                         (fresh vegetables, yogurt)
# 2322   (milk, packaged vegetables fruits, fresh fruits)
# 2366               (packaged vegetables fruits, yogurt)
#
#                                             consequents  antecedent support  \
# 2350                         (fresh vegetables, yogurt)            0.090715
# 2367  (packaged cheese, packaged vegetables fruits, ...            0.144660
# 2335   (milk, packaged vegetables fruits, fresh fruits)            0.144660
# 2322                         (fresh vegetables, yogurt)            0.087450
# 2366  (packaged cheese, fresh vegetables, fresh fruits)            0.127910
#
#       consequent support   support  confidence      lift  leverage  conviction
# 2350            0.144660  0.034565    0.381028  2.633959  0.021442    1.381873
# 2367            0.090715  0.034565    0.238940  2.633959  0.021442    1.194761
# 2335            0.087450  0.032845    0.227050  2.596337  0.020194    1.180606
# 2322            0.144660  0.032845    0.375586  2.596337  0.020194    1.369828
# 2366            0.104570  0.034565    0.270229  2.584193  0.021189    1.227001

# %%
print('Amount of substitues found:',len(ruleLift[(ruleLift['lift'] > 1)]))
# Out:
# Amount of substitues found: 384

# %% [markdown]
# ## Insight:
# ### Too many rules found when decreasing the support threshold from 5% to 2.5%. <br> As a results, the analysis of the complementary itemsets will be continued with minimum support threshold of 5%.

# %% [markdown]
# ## 3.3. Analysing Complementary Itemsets

# %%
rule_Com_new.head()
# Out:
#                            antecedents         consequents  \
# 1     (fresh vegetables, fresh fruits)       (fresh herbs)
# 3          (fresh herbs, fresh fruits)  (fresh vegetables)
# 6                        (fresh herbs)  (fresh vegetables)
# 7                   (fresh vegetables)       (fresh herbs)
# 21  (milk, packaged vegetables fruits)            (yogurt)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 1             0.317560            0.093005  0.061815    0.194656  2.092964
# 3             0.070135            0.444360  0.061815    0.881372  1.983463
# 6             0.093005            0.444360  0.078655    0.845707  1.903203
# 7             0.444360            0.093005  0.078655    0.177007  1.903203
# 21            0.107425            0.263675  0.051295    0.477496  1.810926
#
#     leverage  conviction  length_ant  length_cons
# 1   0.032280    1.126221           2            1
# 3   0.030650    4.683872           2            1
# 6   0.037327    3.601205           1            1
# 7   0.037327    1.102069           1            1
# 21  0.022970    1.409223           2            1

# %%
if len(rule_Com_new) == len(rule_Com_new[rule_Com_new['support'] >= 0.05]):
    print('Correct dataframe')
# Out:
# Correct dataframe

# %% [markdown]
# ## 3.4. Table - Complementary Itemsets (2:1)

# %%
ruleCom_2_1 = rule_Com_new[(rule_Com_new['length_ant'] == 2) & (rule_Com_new['length_cons'] == 1)]
print("Two to one relationship rules found:", len(ruleCom_2_1))
ruleCom_2_1.reset_index(drop=True,inplace=True)
ruleCom_2_1[:20].loc[:,:'conviction']
# Out:
# Two to one relationship rules found: 102
#                                       antecedents  \
# 0                (fresh vegetables, fresh fruits)
# 1                     (fresh herbs, fresh fruits)
# 2              (milk, packaged vegetables fruits)
# 3            (packaged vegetables fruits, yogurt)
# 4                            (milk, fresh fruits)
# 5                        (milk, fresh vegetables)
# 6   (packaged vegetables fruits, packaged cheese)
# 7                      (fresh vegetables, yogurt)
# 8                 (packaged cheese, fresh fruits)
# 9             (fresh vegetables, soy lactosefree)
# 10                 (frozen produce, fresh fruits)
# 11                     (fresh vegetables, yogurt)
# 12             (packaged vegetables fruits, eggs)
# 13            (packaged cheese, fresh vegetables)
# 14           (packaged vegetables fruits, yogurt)
# 15     (packaged vegetables fruits, fresh fruits)
# 16                       (fresh vegetables, eggs)
# 17                         (fresh fruits, yogurt)
# 18                         (fresh fruits, yogurt)
# 19  (packaged vegetables fruits, packaged cheese)
#
#                      consequents  antecedent support  consequent support  \
# 0                  (fresh herbs)            0.317560            0.093005
# 1             (fresh vegetables)            0.070135            0.444360
# 2                       (yogurt)            0.107425            0.263675
# 3              (packaged cheese)            0.127910            0.230995
# 4                       (yogurt)            0.164310            0.263675
# 5                       (yogurt)            0.124715            0.263675
# 6                       (yogurt)            0.114610            0.263675
# 7              (packaged cheese)            0.144660            0.230995
# 8                       (yogurt)            0.155900            0.263675
# 9   (packaged vegetables fruits)            0.094120            0.365415
# 10  (packaged vegetables fruits)            0.089235            0.365415
# 11  (packaged vegetables fruits)            0.144660            0.365415
# 12            (fresh vegetables)            0.068650            0.444360
# 13  (packaged vegetables fruits)            0.135850            0.365415
# 14                        (milk)            0.127910            0.243325
# 15              (frozen produce)            0.269870            0.122580
# 16  (packaged vegetables fruits)            0.084310            0.365415
# 17                        (milk)            0.188225            0.243325
# 18             (packaged cheese)            0.188225            0.230995
# 19            (fresh vegetables)            0.114610            0.444360
#
#      support  confidence      lift  leverage  conviction
# 0   0.061815    0.194656  2.092964  0.032280    1.126221
# 1   0.061815    0.881372  1.983463  0.030650    4.683872
# 2   0.051295    0.477496  1.810926  0.022970    1.409223
# 3   0.051915    0.405871  1.757057  0.022368    1.294341
# 4   0.074860    0.455602  1.727893  0.031536    1.352550
# 5   0.056510    0.453113  1.718453  0.023626    1.346394
# 6   0.051915    0.452971  1.717914  0.021695    1.346044
# 7   0.057195    0.395375  1.711619  0.023779    1.271872
# 8   0.070020    0.449134  1.703362  0.028913    1.336668
# 9   0.057695    0.612994  1.677528  0.023302    1.639729
# 10  0.054415    0.609794  1.668772  0.021807    1.626284
# 11  0.087995    0.608288  1.664651  0.035134    1.620031
# 12  0.050675    0.738165  1.661186  0.020170    2.122097
# 13  0.081970    0.603386  1.651235  0.032328    1.600007
# 14  0.051295    0.401024  1.648101  0.020171    1.263281
# 15  0.054415    0.201634  1.644919  0.021334    1.099020
# 16  0.050675    0.601056  1.644858  0.019867    1.590660
# 17  0.074860    0.397716  1.634503  0.029060    1.256341
# 18  0.070020    0.372002  1.610431  0.026541    1.224533
# 19  0.081970    0.715208  1.609524  0.031042    1.951039

# %% [markdown]
# ## 3.5. Heatmap - Complementary Itemsets (2:1)

# %%
# Import seaborn under its standard alias
import seaborn as sns

# Replace frozen sets with strings
ruleCom_2_1['antecedents_'] = ruleCom_2_1['antecedents'].apply(lambda a: ','.join(list(a)))
ruleCom_2_1['consequents_'] = ruleCom_2_1['consequents'].apply(lambda a: ','.join(list(a)))


# Transform the DataFrame of rules into a matrix using the lift metric
pivot = ruleCom_2_1[ruleCom_2_1['length_ant']==2].pivot(index = 'antecedents_', 
                    columns = 'consequents_', values= 'lift')

# Generate a heatmap with annotations on and the colorbar off
fig, ax = plt.subplots(figsize=(10,12)) 
sns.heatmap(pivot, annot = True, linewidths=.5,ax=ax, cmap="YlGnBu").set_title("Complementaries 2:1")
plt.yticks(rotation=45)
plt.xticks(rotation=45)
plt.savefig('all_coms_heatmap.png',bbox_inches='tight',dpi=250, transparent=True)
plt.show()
# Out:
# <ipython-input-48-299719ae3701>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleCom_2_1['antecedents_'] = ruleCom_2_1['antecedents'].apply(lambda a: ','.join(list(a)))
# <ipython-input-48-299719ae3701>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleCom_2_1['consequents_'] = ruleCom_2_1['consequents'].apply(lambda a: ','.join(list(a)))

# %% [markdown]
# ## 3.6. Table - Complementary Itemsets (1:1)

# %%
ruleCom_1_1 = rule_Com_new[(rule_Com_new['length_ant'] == 1) & (rule_Com_new['length_cons'] == 1)]
print("One to one relationship rules found:", len(ruleCom_1_1))
ruleCom_1_1.reset_index(drop=True,inplace=True)
ruleCom_1_1[:20].loc[:,:'conviction']
# Out:
# One to one relationship rules found: 111
#                      antecedents                   consequents  \
# 0                  (fresh herbs)            (fresh vegetables)
# 1             (fresh vegetables)                 (fresh herbs)
# 2     (canned jarred vegetables)            (fresh vegetables)
# 3           (canned meals beans)            (fresh vegetables)
# 4                        (bread)             (packaged cheese)
# 5              (packaged cheese)                       (bread)
# 6                  (fresh herbs)  (packaged vegetables fruits)
# 7         (fresh dips tapenades)  (packaged vegetables fruits)
# 8                         (milk)                       (bread)
# 9                        (bread)                        (milk)
# 10  (packaged vegetables fruits)              (frozen produce)
# 11              (frozen produce)  (packaged vegetables fruits)
# 12         (soup broth bouillon)            (fresh vegetables)
# 13                        (milk)                      (yogurt)
# 14                      (yogurt)                        (milk)
# 15             (packaged cheese)                      (yogurt)
# 16                      (yogurt)             (packaged cheese)
# 17            (fresh vegetables)  (packaged vegetables fruits)
# 18  (packaged vegetables fruits)            (fresh vegetables)
# 19             (packaged cheese)              (chips pretzels)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.093005            0.444360  0.078655    0.845707  1.903203
# 1             0.444360            0.093005  0.078655    0.177007  1.903203
# 2             0.071890            0.444360  0.055055    0.765823  1.723429
# 3             0.069705            0.444360  0.050435    0.723549  1.628295
# 4             0.163865            0.230995  0.059690    0.364263  1.576931
# 5             0.230995            0.163865  0.059690    0.258404  1.576931
# 6             0.093005            0.365415  0.052535    0.564862  1.545810
# 7             0.098205            0.365415  0.053785    0.547681  1.498791
# 8             0.243325            0.163865  0.059705    0.245371  1.497400
# 9             0.163865            0.243325  0.059705    0.364355  1.497400
# 10            0.365415            0.122580  0.066985    0.183312  1.495449
# 11            0.122580            0.365415  0.066985    0.546459  1.495449
# 12            0.083365            0.444360  0.055380    0.664308  1.494976
# 13            0.243325            0.263675  0.095705    0.393322  1.491691
# 14            0.263675            0.243325  0.095705    0.362966  1.491691
# 15            0.230995            0.263675  0.088520    0.383212  1.453349
# 16            0.263675            0.230995  0.088520    0.335716  1.453349
# 17            0.444360            0.365415  0.234555    0.527849  1.444519
# 18            0.365415            0.444360  0.234555    0.641887  1.444519
# 19            0.230995            0.169435  0.056405    0.244183  1.441159
#
#     leverage  conviction
# 0   0.037327    3.601205
# 1   0.037327    1.102069
# 2   0.023110    2.372733
# 3   0.019461    2.009906
# 4   0.021838    1.209628
# 5   0.021838    1.127480
# 6   0.018550    1.458354
# 7   0.017899    1.402959
# 8   0.019833    1.108009
# 9   0.019833    1.190405
# 10  0.022192    1.074364
# 11  0.022192    1.399180
# 12  0.018336    1.655206
# 13  0.031546    1.213699
# 14  0.031546    1.187809
# 15  0.027612    1.193805
# 16  0.027612    1.157645
# 17  0.072179    1.344030
# 18  0.072179    1.551576
# 19  0.017266    1.098897

# %% [markdown]
# ## 3.7. Heatmap - Complementary Itemsets (1:1)

# %%
# Import seaborn under its standard alias
import seaborn as sns

# Replace frozen sets with strings
ruleCom_1_1['antecedents_'] = ruleCom_1_1['antecedents'].apply(lambda a: ','.join(list(a)))
ruleCom_1_1['consequents_'] = ruleCom_1_1['consequents'].apply(lambda a: ','.join(list(a)))


# Transform the DataFrame of rules into a matrix using the lift metric
pivot = ruleCom_1_1[ruleCom_1_1['length_ant']==1].pivot(index = 'antecedents_', 
                    columns = 'consequents_', values= 'lift')

# Generate a heatmap with annotations on and the colorbar off
fig, ax = plt.subplots(figsize=(10,12)) 
sns.heatmap(pivot, annot = True,linewidths=.5,ax=ax, cmap="YlGnBu").set_title("Complementaries 1:1")
plt.yticks(rotation=0)
plt.xticks(rotation=45)
plt.savefig('all_coms_heatmap.png',bbox_inches='tight',dpi=250, transparent=True)
plt.show()
# Out:
# <ipython-input-50-9823a6d63fba>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleCom_1_1['antecedents_'] = ruleCom_1_1['antecedents'].apply(lambda a: ','.join(list(a)))
# <ipython-input-50-9823a6d63fba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ruleCom_1_1['consequents_'] = ruleCom_1_1['consequents'].apply(lambda a: ','.join(list(a)))

# %% [markdown]
# ## 3.7. Table - Complementary Itemsets with Conviction Constraints

# %%
ruleComConv = ruleCom_1_1[ruleCom_1_1['conviction'] >= 1.3].reset_index(drop=True)
print('Rule found with the new striction:', len(ruleComConv))
ruleComConv.loc[:,:'conviction']
# Out:
# Rule found with the new striction: 31
#                      antecedents                   consequents  \
# 0                  (fresh herbs)            (fresh vegetables)
# 1     (canned jarred vegetables)            (fresh vegetables)
# 2           (canned meals beans)            (fresh vegetables)
# 3                  (fresh herbs)  (packaged vegetables fruits)
# 4         (fresh dips tapenades)  (packaged vegetables fruits)
# 5               (frozen produce)  (packaged vegetables fruits)
# 6          (soup broth bouillon)            (fresh vegetables)
# 7             (fresh vegetables)  (packaged vegetables fruits)
# 8   (packaged vegetables fruits)            (fresh vegetables)
# 9               (frozen produce)            (fresh vegetables)
# 10                  (lunch meat)  (packaged vegetables fruits)
# 11                        (eggs)            (fresh vegetables)
# 12                 (fresh herbs)                (fresh fruits)
# 13        (other creams cheeses)            (fresh vegetables)
# 14  (packaged vegetables fruits)                (fresh fruits)
# 15        (fresh dips tapenades)            (fresh vegetables)
# 16             (packaged cheese)            (fresh vegetables)
# 17              (frozen produce)                (fresh fruits)
# 18                  (lunch meat)            (fresh vegetables)
# 19            (fresh vegetables)                (fresh fruits)
# 20                      (yogurt)                (fresh fruits)
# 21        (fresh dips tapenades)                (fresh fruits)
# 22                        (eggs)                (fresh fruits)
# 23             (soy lactosefree)                (fresh fruits)
# 24                  (lunch meat)                (fresh fruits)
# 25         (energy granola bars)                (fresh fruits)
# 26                       (bread)                (fresh fruits)
# 27                     (spreads)                (fresh fruits)
# 28      (nuts seeds dried fruit)                (fresh fruits)
# 29                        (milk)                (fresh fruits)
# 30             (packaged cheese)                (fresh fruits)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.093005            0.444360  0.078655    0.845707  1.903203
# 1             0.071890            0.444360  0.055055    0.765823  1.723429
# 2             0.069705            0.444360  0.050435    0.723549  1.628295
# 3             0.093005            0.365415  0.052535    0.564862  1.545810
# 4             0.098205            0.365415  0.053785    0.547681  1.498791
# 5             0.122580            0.365415  0.066985    0.546459  1.495449
# 6             0.083365            0.444360  0.055380    0.664308  1.494976
# 7             0.444360            0.365415  0.234555    0.527849  1.444519
# 8             0.365415            0.444360  0.234555    0.641887  1.444519
# 9             0.122580            0.444360  0.077750    0.634280  1.427400
# 10            0.103890            0.365415  0.053225    0.512321  1.402024
# 11            0.136490            0.444360  0.084310    0.617701  1.390091
# 12            0.093005            0.555995  0.070135    0.754099  1.356306
# 13            0.086485            0.444360  0.052105    0.602474  1.355825
# 14            0.365415            0.555995  0.269870    0.738530  1.328304
# 15            0.098205            0.444360  0.057955    0.590143  1.328074
# 16            0.230995            0.444360  0.135850    0.588108  1.323494
# 17            0.122580            0.555995  0.089235    0.727974  1.309317
# 18            0.103890            0.444360  0.060095    0.578448  1.301756
# 19            0.444360            0.555995  0.317560    0.714646  1.285346
# 20            0.263675            0.555995  0.188225    0.713852  1.283919
# 21            0.098205            0.555995  0.069040    0.703019  1.264434
# 22            0.136490            0.555995  0.095325    0.698403  1.256131
# 23            0.168355            0.555995  0.117480    0.697811  1.255067
# 24            0.103890            0.555995  0.072290    0.695832  1.251508
# 25            0.086545            0.555995  0.059450    0.686926  1.235489
# 26            0.163865            0.555995  0.112410    0.685992  1.233809
# 27            0.078185            0.555995  0.053560    0.685042  1.232101
# 28            0.080225            0.555995  0.054750    0.682456  1.227449
# 29            0.243325            0.555995  0.164310    0.675270  1.214525
# 30            0.230995            0.555995  0.155900    0.674906  1.213871
#
#     leverage  conviction
# 0   0.037327    3.601205
# 1   0.023110    2.372733
# 2   0.019461    2.009906
# 3   0.018550    1.458354
# 4   0.017899    1.402959
# 5   0.022192    1.399180
# 6   0.018336    1.655206
# 7   0.072179    1.344030
# 8   0.072179    1.551576
# 9   0.023280    1.519303
# 10  0.015262    1.301234
# 11  0.023659    1.453417
# 12  0.018425    1.805627
# 13  0.013675    1.397747
# 14  0.066701    1.698112
# 15  0.014317    1.355693
# 16  0.033205    1.348994
# 17  0.021081    1.632213
# 18  0.013930    1.318083
# 19  0.070498    1.555978
# 20  0.041623    1.551664
# 21  0.014439    1.495063
# 22  0.019437    1.472179
# 23  0.023875    1.469297
# 24  0.014528    1.459737
# 25  0.011331    1.418210
# 26  0.021302    1.413990
# 27  0.010090    1.409727
# 28  0.010145    1.398245
# 29  0.029023    1.367304
# 30  0.027468    1.365776

# %% [markdown]
# ## 3.8. Heatmap - Complementary Itemsets with Conviction Constraints

# %%
# Import seaborn under its standard alias
import seaborn as sns

# Replace frozen sets with strings
ruleComConv['antecedents_'] = ruleComConv['antecedents'].apply(lambda a: ','.join(list(a)))
ruleComConv['consequents_'] = ruleComConv['consequents'].apply(lambda a: ','.join(list(a)))


# Transform the DataFrame of rules into a matrix using the lift metric
pivot = ruleComConv[ruleComConv['length_ant']==1].pivot(index = 'antecedents_', 
                    columns = 'consequents_', values= 'lift')

# Generate a heatmap with annotations on and the colorbar off
fig, ax = plt.subplots(figsize=(10,12)) 
sns.heatmap(pivot, annot = True,linewidths=.5,ax=ax, cmap="YlGnBu").set_title("Complementaries 1:1 with Conviction Constraints")
plt.yticks(rotation=0)
plt.xticks(rotation=45)
plt.savefig('all_coms_conv_heatmap.png',bbox_inches='tight',dpi=250, transparent=True)
plt.show()
